# %% [markdown]
# <a href="https://colab.research.google.com/github/LUCASBECKERAI-star/ALGORITHM-A-RAUSCHECKER-UCSF/blob/main/MRI_CT_Converter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Flask
# !pip install pyngrok

# %%
from pyngrok import ngrok

ngrok.set_auth_token("<2pFiBFEzQSBlNFDYR3kdzYsseVt_3TqGZ5RncfdYKnzdoReWA>")

# %%
# %env NGROK_AUTHTOKEN=2pFiBFEzQSBlNFDYR3kdzYsseVt_3TqGZ5RncfdYKnzdoReWA
# Out:
# env: NGROK_AUTHTOKEN=2pFiBFEzQSBlNFDYR3kdzYsseVt_3TqGZ5RncfdYKnzdoReWA

# %%
from pyngrok import ngrok
import os

# Get the authtoken from environment variables
auth_token = os.getenv("NGROK_AUTHTOKEN")
ngrok.set_auth_token(auth_token)

# %%
from flask import Flask, render_template, request
from pyngrok import ngrok
import os

# Create Flask app
app = Flask(__name__)

# Home route to render the upload form
@app.route('/')
def index():
    return '''
    <!DOCTYPE html>
    <html lang="en">
    <head>
        <meta charset="UTF-8">
        <meta name="viewport" content="width=device-width, initial-scale=1.0">
        <title>MRI to CT Converter Interface</title>
        <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.0.0-beta3/css/all.min.css">
        <style>
            body {
                font-family: Arial, sans-serif;
                background-color: #f4f4f4;
                display: flex;
                justify-content: center;
                align-items: center;
                height: 100vh;
                margin: 0;
            }
            .upload-container {
                background: #fff;
                padding: 30px;
                border-radius: 10px;
                box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
                text-align: center;
                max-width: 500px;
                width: 100%;
            }
            .upload-container h2 {
                margin-bottom: 20px;
                font-size: 24px;
                color: #333;
            }
            .drag-drop {
                border: 2px dashed #aaa;
                border-radius: 10px;
                padding: 50px;
                background-color: #fafafa;
                color: #333;
                cursor: pointer;
                transition: background-color 0.3s;
            }
            .drag-drop:hover {
                background-color: #f0f0f0;
            }
            .upload-container button {
                margin-top: 20px;
                padding: 10px 20px;
                border: none;
                border-radius: 5px;
                background-color: #007bff;
                color: #fff;
                font-size: 16px;
                cursor: pointer;
                transition: background-color 0.3s;
            }
            .upload-container button:hover {
                background-color: #0056b3;
            }
        </style>
    </head>
    <body>
        <div class="upload-container">
            <h2>Upload MRI Sequences for CT Generation</h2>
            <form action="/upload" method="post" enctype="multipart/form-data">
                <div class="drag-drop" onclick="document.getElementById('fileInput').click()">
                    <i class="fas fa-upload fa-3x"></i>
                    <p>Drag & Drop DICOM Files Here<br>or Click to Browse</p>
                    <input type="file" id="fileInput" name="fileInput" multiple accept=".dcm" style="display: none;">
                </div>
                <button type="submit">Upload & Generate CT</button>
            </form>
        </div>
    </body>
    </html>
    '''

# File upload handling route
@app.route('/upload', methods=['POST'])
def upload():
    if 'fileInput' not in request.files:
        return "No file part", 400

    files = request.files.getlist('fileInput')
    if not files:
        return "No files selected", 400

    # Save files and process them as needed (dummy implementation for now)
    save_path = "uploads/"
    os.makedirs(save_path, exist_ok=True)

    for file in files:
        file.save(os.path.join(save_path, file.filename))

    return "Files uploaded successfully, CT generation will start shortly.", 200

# Running Flask application in Colab
if __name__ == '__main__':
    # Set up ngrok and Flask server
    port = 5000
    public_url = ngrok.connect(port)
    print(f" * ngrok tunnel "{public_url}" -> "http://127.0.0.1:{port}")

    # Start Flask server
    app.run(port=port)
# Out:
#   File "<ipython-input-13-e1e66c6a1c7b>", line 111
#     print(f" * ngrok tunnel "{public_url}" -> "http://127.0.0.1:{port}")
#                                                                       ^
# SyntaxError: unterminated string literal (detected at line 111)

# %%
from flask import Flask, render_template, request
from pyngrok import ngrok
import os

# Create Flask app
app = Flask(__name__)

# Home route to render the upload form
@app.route('/')
def index():
    return '''
    <!DOCTYPE html>
    <html lang="en">
    <head>
        <meta charset="UTF-8">
        <meta name="viewport" content="width=device-width, initial-scale=1.0">
        <title>MRI to CT Converter Interface</title>
        <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.0.0-beta3/css/all.min.css">
        <style>
            body {
                font-family: Arial, sans-serif;
                background-color: #f4f4f4;
                display: flex;
                justify-content: center;
                align-items: center;
                height: 100vh;
                margin: 0;
            }
            .upload-container {
                background: #fff;
                padding: 30px;
                border-radius: 10px;
                box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
                text-align: center;
                max-width: 500px;
                width: 100%;
            }
            .upload-container h2 {
                margin-bottom: 20px;
                font-size: 24px;
                color: #333;
            }
            .drag-drop {
                border: 2px dashed #aaa;
                border-radius: 10px;
                padding: 50px;
                background-color: #fafafa;
                color: #333;
                cursor: pointer;
                transition: background-color 0.3s;
            }
            .drag-drop:hover {
                background-color: #f0f0f0;
            }
            .upload-container button {
                margin-top: 20px;
                padding: 10px 20px;
                border: none;
                border-radius: 5px;
                background-color: #007bff;
                color: #fff;
                font-size: 16px;
                cursor: pointer;
                transition: background-color 0.3s;
            }
            .upload-container button:hover {
                background-color: #0056b3;
            }
        </style>
    </head>
    <body>
        <div class="upload-container">
            <h2>Upload MRI Sequences for CT Generation</h2>
            <form action="/upload" method="post" enctype="multipart/form-data">
                <div class="drag-drop" onclick="document.getElementById('fileInput').click()">
                    <i class="fas fa-upload fa-3x"></i>
                    <p>Drag & Drop DICOM Files Here<br>or Click to Browse</p>
                    <input type="file" id="fileInput" name="fileInput" multiple accept=".dcm" style="display: none;">
                </div>
                <button type="submit">Upload & Generate CT</button>
            </form>
        </div>
    </body>
    </html>
    '''

# File upload handling route
@app.route('/upload', methods=['POST'])
def upload():
    if 'fileInput' not in request.files:
        return "No file part", 400

    files = request.files.getlist('fileInput')
    if not files:
        return "No files selected", 400

    # Save files and process them as needed (dummy implementation for now)
    save_path = "uploads/"
    os.makedirs(save_path, exist_ok=True)

    for file in files:
        file.save(os.path.join(save_path, file.filename))

    return "Files uploaded successfully, CT generation will start shortly.", 200

# Running Flask application in Colab
if __name__ == '__main__':
    # Set up ngrok and Flask server
    port = 5000
    public_url = ngrok.connect(port)
    print(f" * ngrok tunnel \"{public_url}\" -> \"http://127.0.0.1:{port}\"")

    # Start Flask server
    app.run(port=port)
# Out:
#  * ngrok tunnel "NgrokTunnel: "https://bf35-35-227-26-56.ngrok-free.app" -> "http://localhost:5000"" -> "http://127.0.0.1:5000"
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [23/Nov/2024 13:32:09] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Nov/2024 13:32:09] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [23/Nov/2024 13:36:29] "GET / HTTP/1.1" 200 -

# %%
# !pip install pyngrok
# Out:
# ERROR:root:Unexpected exception finding object shape
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/_debugpy_repr.py", line 54, in get_shape
#     shape = getattr(obj, 'shape', None)
#   File "/usr/local/lib/python3.10/dist-packages/werkzeug/local.py", line 318, in __get__
#     obj = instance._get_current_object()
#   File "/usr/local/lib/python3.10/dist-packages/werkzeug/local.py", line 519, in _get_current_object
#     raise RuntimeError(unbound_message) from None
# RuntimeError: Working outside of request context.
#
# This typically means that you attempted to use functionality that needed
# an active HTTP request. Consult the documentation on testing for
# information about how to avoid this problem.
# ...

# %%
# !pip install Flask

# %%
from flask import Flask, render_template, request, redirect, url_for
from pyngrok import ngrok
import os
import time

# Create Flask app
app = Flask(__name__)

# Home route to render the loading animation page
@app.route('/')
def loading():
    return '''
    <!DOCTYPE html>
    <html lang="en">
    <head>
        <meta charset="UTF-8">
        <meta name="viewport" content="width=device-width, initial-scale=1.0">
        <title>MRI to CT Conversion - Intro</title>
        <style>
            body, html {
                height: 100%;
                margin: 0;
                overflow: hidden;
                font-family: 'Arial', sans-serif;
                background: #000;
            }

            .intro-container {
                height: 100%;
                width: 100%;
                display: flex;
                justify-content: center;
                align-items: center;
                flex-direction: column;
                color: #fff;
                text-align: center;
                position: relative;
            }

            .intro-container .glow-text {
                font-size: 3em;
                text-transform: uppercase;
                animation: glow 1.5s ease-in-out infinite alternate;
            }

            @keyframes glow {
                from {
                    text-shadow: 0 0 5px #fff, 0 0 10px #0ff, 0 0 15px #0ff, 0 0 20px #0ff, 0 0 25px #0ff, 0 0 30px #0ff;
                }
                to {
                    text-shadow: 0 0 10px #fff, 0 0 20px #0ff, 0 0 30px #0ff, 0 0 40px #0ff, 0 0 50px #0ff, 0 0 60px #0ff;
                }
            }

            .fade-in-text {
                animation: fadeIn 5s ease-in-out forwards;
                opacity: 0;
                font-size: 2em;
                margin-top: 20px;
            }

            @keyframes fadeIn {
                0% { opacity: 0; transform: translateY(20px); }
                100% { opacity: 1; transform: translateY(0); }
            }

            .loading-circles {
                position: absolute;
                bottom: 10%;
                display: flex;
                gap: 10px;
            }

            .circle {
                width: 15px;
                height: 15px;
                background-color: #0ff;
                border-radius: 50%;
                animation: bounce 1.5s infinite ease-in-out;
            }

            .circle:nth-child(2) {
                animation-delay: 0.2s;
            }

            .circle:nth-child(3) {
                animation-delay: 0.4s;
            }

            @keyframes bounce {
                0%, 100% { transform: translateY(0); }
                50% { transform: translateY(-15px); }
            }

        </style>
    </head>
    <body>
        <div class="intro-container">
            <div class="glow-text">Welcome to MRI to CT Conversion</div>
            <div class="fade-in-text" style="animation-delay: 1s;">Willkommen zur MRT zu CT Konvertierung</div>
            <div class="fade-in-text" style="animation-delay: 2s;">Bienvenue dans la conversion IRM en CT</div>
            <div class="fade-in-text" style="animation-delay: 3s;">欢迎转换MRI到CT</div>
            <div class="loading-circles">
                <div class="circle"></div>
                <div class="circle"></div>
                <div class="circle"></div>
            </div>
        </div>
        <script>
            setTimeout(function() {
                window.location.href = '/main';
            }, 5000); // Redirect to main page after 5 seconds
        </script>
    </body>
    </html>
    '''

# Main interface route to render the upload form
@app.route('/main')
def main_interface():
    return '''
    <!DOCTYPE html>
    <html lang="en">
    <head>
        <meta charset="UTF-8">
        <meta name="viewport" content="width=device-width, initial-scale=1.0">
        <title>MRI to CT Converter Interface</title>
        <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.0.0-beta3/css/all.min.css">
        <style>
            body {
                font-family: Arial, sans-serif;
                background-color: #f4f4f4;
                display: flex;
                justify-content: center;
                align-items: center;
                height: 100vh;
                margin: 0;
            }
            .upload-container {
                background: #fff;
                padding: 30px;
                border-radius: 10px;
                box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
                text-align: center;
                max-width: 500px;
                width: 100%;
            }
            .upload-container h2 {
                margin-bottom: 20px;
                font-size: 24px;
                color: #333;
            }
            .drag-drop {
                border: 2px dashed #aaa;
                border-radius: 10px;
                padding: 50px;
                background-color: #fafafa;
                color: #333;
                cursor: pointer;
                transition: background-color 0.3s;
            }
            .drag-drop:hover {
                background-color: #f0f0f0;
            }
            .upload-container button {
                margin-top: 20px;
                padding: 10px 20px;
                border: none;
                border-radius: 5px;
                background-color: #007bff;
                color: #fff;
                font-size: 16px;
                cursor: pointer;
                transition: background-color 0.3s;
            }
            .upload-container button:hover {
                background-color: #0056b3;
            }
        </style>
    </head>
    <body>
        <div class="upload-container">
            <h2>Upload MRI Sequences for CT Generation</h2>
            <form action="/upload" method="post" enctype="multipart/form-data">
                <div class="drag-drop" onclick="document.getElementById('fileInput').click()">
                    <i class="fas fa-upload fa-3x"></i>
                    <p>Drag & Drop DICOM Files Here<br>or Click to Browse</p>
                    <input type="file" id="fileInput" name="fileInput" multiple accept=".dcm" style="display: none;">
                </div>
                <button type="submit">Upload & Generate CT</button>
            </form>
        </div>
    </body>
    </html>
    '''

# File upload handling route
@app.route('/upload', methods=['POST'])
def upload():
    if 'fileInput' not in request.files:
        return "No file part", 400

    files = request.files.getlist('fileInput')
    if not files:
        return "No files selected", 400

    # Save files and process them as needed (dummy implementation for now)
    save_path = "uploads/"
    os.makedirs(save_path, exist_ok=True)

    for file in files:
        file.save(os.path.join(save_path, file.filename))

    return "Files uploaded successfully, CT generation will start shortly.", 200

# Running Flask application in Colab
if __name__ == '__main__':
    # Set up ngrok and Flask server
    port = 5000
    public_url = ngrok.connect(port)
    print(f" * ngrok tunnel \"{public_url}\" -> \"http://127.0.0.1:{port}\"")

    # Start Flask server
    app.run(port=port)
# Out:
# ERROR:pyngrok.process.ngrok:t=2024-11-23T16:10:53+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ERROR:pyngrok.process.ngrok:t=2024-11-23T16:10:53+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ...

# %%
# !ngrok authtoken <2pG2tVT5C3WyJDyECFl1VmCbHUy_3aBMS4S74P4qwPPzdDSeM>
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `newline'
# /bin/bash: -c: line 1: `ngrok authtoken <2pG2tVT5C3WyJDyECFl1VmCbHUy_3aBMS4S74P4qwPPzdDSeM>'

# %%
from pyngrok import ngrok

ngrok.set_auth_token("2pG2tVT5C3WyJDyECFl1VmCbHUy_3aBMS4S74P4qwPPzdDSeM")

# %%
from flask import Flask, render_template, request, redirect, url_for
from pyngrok import ngrok
import os
import time

# Create Flask app
app = Flask(__name__)

# Home route to render the loading animation page
@app.route('/')
def loading():
    return '''
    <!DOCTYPE html>
    <html lang="en">
    <head>
        <meta charset="UTF-8">
        <meta name="viewport" content="width=device-width, initial-scale=1.0">
        <title>MRI to CT Conversion - Intro</title>
        <style>
            body, html {
                height: 100%;
                margin: 0;
                overflow: hidden;
                font-family: 'Arial', sans-serif;
                background: #000;
            }

            .intro-container {
                height: 100%;
                width: 100%;
                display: flex;
                justify-content: center;
                align-items: center;
                flex-direction: column;
                color: #fff;
                text-align: center;
                position: relative;
            }

            .intro-container .glow-text {
                font-size: 3em;
                text-transform: uppercase;
                animation: glow 1.5s ease-in-out infinite alternate;
            }

            @keyframes glow {
                from {
                    text-shadow: 0 0 5px #fff, 0 0 10px #0ff, 0 0 15px #0ff, 0 0 20px #0ff, 0 0 25px #0ff, 0 0 30px #0ff;
                }
                to {
                    text-shadow: 0 0 10px #fff, 0 0 20px #0ff, 0 0 30px #0ff, 0 0 40px #0ff, 0 0 50px #0ff, 0 0 60px #0ff;
                }
            }

            .fade-in-text {
                animation: fadeIn 5s ease-in-out forwards;
                opacity: 0;
                font-size: 2em;
                margin-top: 20px;
            }

            @keyframes fadeIn {
                0% { opacity: 0; transform: translateY(20px); }
                100% { opacity: 1; transform: translateY(0); }
            }

            .loading-circles {
                position: absolute;
                bottom: 10%;
                display: flex;
                gap: 10px;
            }

            .circle {
                width: 15px;
                height: 15px;
                background-color: #0ff;
                border-radius: 50%;
                animation: bounce 1.5s infinite ease-in-out;
            }

            .circle:nth-child(2) {
                animation-delay: 0.2s;
            }

            .circle:nth-child(3) {
                animation-delay: 0.4s;
            }

            @keyframes bounce {
                0%, 100% { transform: translateY(0); }
                50% { transform: translateY(-15px); }
            }

        </style>
    </head>
    <body>
        <div class="intro-container">
            <div class="glow-text">Welcome to MRI to CT Conversion</div>
            <div class="fade-in-text" style="animation-delay: 1s;">Willkommen zur MRT zu CT Konvertierung</div>
            <div class="fade-in-text" style="animation-delay: 2s;">Bienvenue dans la conversion IRM en CT</div>
            <div class="fade-in-text" style="animation-delay: 3s;">欢迎转换MRI到CT</div>
            <div class="loading-circles">
                <div class="circle"></div>
                <div class="circle"></div>
                <div class="circle"></div>
            </div>
        </div>
        <script>
            setTimeout(function() {
                window.location.href = '/main';
            }, 5000); // Redirect to main page after 5 seconds
        </script>
    </body>
    </html>
    '''

# Main interface route to render the upload form
@app.route('/main')
def main_interface():
    return '''
    <!DOCTYPE html>
    <html lang="en">
    <head>
        <meta charset="UTF-8">
        <meta name="viewport" content="width=device-width, initial-scale=1.0">
        <title>MRI to CT Converter Interface</title>
        <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.0.0-beta3/css/all.min.css">
        <style>
            body {
                font-family: Arial, sans-serif;
                background-color: #f4f4f4;
                display: flex;
                justify-content: center;
                align-items: center;
                height: 100vh;
                margin: 0;
            }
            .upload-container {
                background: #fff;
                padding: 30px;
                border-radius: 10px;
                box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
                text-align: center;
                max-width: 500px;
                width: 100%;
            }
            .upload-container h2 {
                margin-bottom: 20px;
                font-size: 24px;
                color: #333;
            }
            .drag-drop {
                border: 2px dashed #aaa;
                border-radius: 10px;
                padding: 50px;
                background-color: #fafafa;
                color: #333;
                cursor: pointer;
                transition: background-color 0.3s;
            }
            .drag-drop:hover {
                background-color: #f0f0f0;
            }
            .upload-container button {
                margin-top: 20px;
                padding: 10px 20px;
                border: none;
                border-radius: 5px;
                background-color: #007bff;
                color: #fff;
                font-size: 16px;
                cursor: pointer;
                transition: background-color 0.3s;
            }
            .upload-container button:hover {
                background-color: #0056b3;
            }
        </style>
    </head>
    <body>
        <div class="upload-container">
            <h2>Upload MRI Sequences for CT Generation</h2>
            <form action="/upload" method="post" enctype="multipart/form-data">
                <div class="drag-drop" onclick="document.getElementById('fileInput').click()">
                    <i class="fas fa-upload fa-3x"></i>
                    <p>Drag & Drop DICOM Files Here<br>or Click to Browse</p>
                    <input type="file" id="fileInput" name="fileInput" multiple accept=".dcm" style="display: none;">
                </div>
                <button type="submit">Upload & Generate CT</button>
            </form>
        </div>
    </body>
    </html>
    '''

# File upload handling route
@app.route('/upload', methods=['POST'])
def upload():
    if 'fileInput' not in request.files:
        return "No file part", 400

    files = request.files.getlist('fileInput')
    if not files:
        return "No files selected", 400

    # Save files and process them as needed (dummy implementation for now)
    save_path = "uploads/"
    os.makedirs(save_path, exist_ok=True)

    for file in files:
        file.save(os.path.join(save_path, file.filename))

    return "Files uploaded successfully, CT generation will start shortly.", 200

# Running Flask application in Colab
if __name__ == '__main__':
    # Set up ngrok and Flask server
    port = 5000
    public_url = ngrok.connect(port)
    print(f" * ngrok tunnel \"{public_url}\" -> \"http://127.0.0.1:{port}\"")

    # Start Flask server
    app.run(port=port)
# Out:
#  * ngrok tunnel "NgrokTunnel: "https://858b-34-81-85-126.ngrok-free.app" -> "http://localhost:5000"" -> "http://127.0.0.1:5000"
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [23/Nov/2024 16:13:51] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Nov/2024 16:13:51] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [23/Nov/2024 16:13:56] "GET /main HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Nov/2024 16:16:50] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Nov/2024 16:16:55] "GET /main HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Nov/2024 16:25:57] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Nov/2024 16:26:02] "GET /main HTTP/1.1" 200 -
# ...
